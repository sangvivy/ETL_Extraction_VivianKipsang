# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random

# Define hospital and visit reason options
hospitals = ['City Hospital', 'Green Valley Clinic', 'Sunrise Health', 'Oakwood Medical Center']
visit_reasons = ['Flu', 'Routine Checkup', 'Injury', 'Allergy', 'Surgery Consultation', 'COVID-19 Test']

# Create date range from April 1 to May 31, 2025
date_range = pd.date_range(start='2025-04-01', end='2025-05-31')
data = []

for date in date_range:
    for _ in range(random.randint(5, 10)):  # 5–10 visits per day
        visit_time = datetime.combine(date, datetime.min.time()) + timedelta(
            hours=random.randint(7, 17), minutes=random.randint(0, 59)
        )
        check_out_time = visit_time + timedelta(minutes=random.randint(15, 120))
        data.append({
            'patient_id': random.randint(50000, 99999),
            'hospital': random.choice(hospitals),
            'visit_date': date.date().isoformat(),
            'visit_reason': random.choice(visit_reasons),
            'cost': random.randint(50, 1500),
            'check_out_time': check_out_time.isoformat()
        })

# Save dataset to CSV and preview
df = pd.DataFrame(data)
df.to_csv('hospital_visits_apr_may.csv', index=False)
df.head(60)
# Out:
#     patient_id                hospital  visit_date          visit_reason  \
# 0        53246     Green Valley Clinic  2025-04-01  Surgery Consultation
# 1        90424  Oakwood Medical Center  2025-04-01       Routine Checkup
# 2        88606          Sunrise Health  2025-04-01         COVID-19 Test
# 3        87403  Oakwood Medical Center  2025-04-01         COVID-19 Test
# 4        88520  Oakwood Medical Center  2025-04-01               Allergy
# 5        87261     Green Valley Clinic  2025-04-01                Injury
# 6        77600     Green Valley Clinic  2025-04-01                   Flu
# 7        83339  Oakwood Medical Center  2025-04-01  Surgery Consultation
# 8        84973          Sunrise Health  2025-04-01                   Flu
# 9        82154  Oakwood Medical Center  2025-04-01               Allergy
# 10       93343          Sunrise Health  2025-04-02       Routine Checkup
# 11       96488           City Hospital  2025-04-02  Surgery Consultation
# 12       71390     Green Valley Clinic  2025-04-02               Allergy
# 13       81572     Green Valley Clinic  2025-04-02       Routine Checkup
# 14       80204          Sunrise Health  2025-04-02                Injury
# 15       76920  Oakwood Medical Center  2025-04-02                Injury
# 16       68611  Oakwood Medical Center  2025-04-02       Routine Checkup
# 17       96884          Sunrise Health  2025-04-02       Routine Checkup
# 18       66080           City Hospital  2025-04-02  Surgery Consultation
# 19       53438           City Hospital  2025-04-03                Injury
# 20       50563           City Hospital  2025-04-03         COVID-19 Test
# 21       84497          Sunrise Health  2025-04-03         COVID-19 Test
# 22       93164     Green Valley Clinic  2025-04-03  Surgery Consultation
# 23       52078     Green Valley Clinic  2025-04-03                   Flu
# 24       89434  Oakwood Medical Center  2025-04-03       Routine Checkup
# 25       54181  Oakwood Medical Center  2025-04-03                   Flu
# 26       63836           City Hospital  2025-04-03               Allergy
# 27       53139     Green Valley Clinic  2025-04-04         COVID-19 Test
# 28       90022           City Hospital  2025-04-04                   Flu
# 29       91547           City Hospital  2025-04-04                   Flu
# 30       85273  Oakwood Medical Center  2025-04-04       Routine Checkup
# 30   400  2025-04-04T09:39:00
# 31  1033  2025-04-04T18:36:00
# 32  1335  2025-04-04T08:26:00
# 33   119  2025-04-04T13:33:00
# 34  1366  2025-04-04T10:22:00
# 35   495  2025-04-04T09:48:00
# 36  1038  2025-04-05T14:05:00
# 37   950  2025-04-05T12:33:00
# 38   981  2025-04-05T15:28:00
# 39   925  2025-04-05T11:43:00
# 40  1172  2025-04-05T17:22:00
# 41   714  2025-04-05T12:10:00
# 42   908  2025-04-05T14:42:00
# 43  1377  2025-04-05T10:27:00
# 44   398  2025-04-05T17:42:00
# 45   611  2025-04-06T11:08:00
# 46   257  2025-04-06T08:29:00
# 47    54  2025-04-06T10:53:00
# 48  1218  2025-04-06T11:03:00
# 49  1385  2025-04-06T12:24:00
# 50   688  2025-04-06T18:22:00
# 51   849  2025-04-06T12:01:00
# 52   804  2025-04-06T14:17:00
# 53   856  2025-04-07T14:56:00
# 54   968  2025-04-07T10:07:00
# 55    95  2025-04-07T17:10:00
# 56   291  2025-04-07T09:47:00
# 57   662  2025-04-07T10:23:00
# 58   465  2025-04-07T10:41:00
# 59   412  2025-04-07T16:14:00

# %%
 # FULL EXTRACTION
df_full = pd.read_csv("hospital_visits.csv", parse_dates=["check_out_time"])
print(f"Pulled {len(df_full)} rows via full extraction.")
df_full.head()
# Out:
# Pulled 453 rows via full extraction.
#    patient_id                hospital  visit_date          visit_reason  cost  \
# 0       60542          Sunrise Health  2025-04-02  Surgery Consultation   332
# 1       72600  Oakwood Medical Center  2025-04-02                Injury   194
# 2       75961  Oakwood Medical Center  2025-04-02                Injury  1076
# 3       96648     Green Valley Clinic  2025-04-02       Routine Checkup  1468
# 4       81979     Green Valley Clinic  2025-04-02               Allergy    64
#
#        check_out_time
# 0 2025-04-02 10:00:00
# 1 2025-04-02 14:01:00
# 2 2025-04-02 15:38:00
# 3 2025-04-02 11:09:00
# 4 2025-04-02 10:14:00

# %%
# Set initial last extraction time (e.g., halfway through the data range)
with open("last_extraction.txt", "w") as f:
    f.write("2025-04-20 12:00:00")

# %%
# INCREMENTAL EXTRACTION

with open("last_extraction.txt", "r") as f:
    last_extraction = f.read().strip()
    
df = pd.read_csv("hospital_visits.csv", parse_dates=["check_out_time"])
last_extraction_time = pd.to_datetime(last_extraction)
df_incremental = df[df['check_out_time'] > last_extraction_time]
print(f"Pulled {len(df_incremental)} new/updated rows since {last_extraction}.")
df_incremental.head()
# Out:
# Pulled 0 new/updated rows since 2025-05-31 19:42:00.
# Empty DataFrame
# Columns: [patient_id, hospital, visit_date, visit_reason, cost, check_out_time]
# Index: []

# %%
# Get the most recent update
new_checkpoint = df['check_out_time'].max()

# %%
# Save it
with open("last_extraction.txt", "w") as f:
    f.write(new_checkpoint.isoformat())
print(f"Updated last_extraction.txt to {new_checkpoint}")
# Out:
# Updated last_extraction.txt to 2025-05-31 14:34:00
