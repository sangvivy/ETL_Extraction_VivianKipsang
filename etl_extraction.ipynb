# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random

# Define hospital and visit reason options
hospitals = ['City Hospital', 'Green Valley Clinic', 'Sunrise Health', 'Oakwood Medical Center']
visit_reasons = ['Flu', 'Routine Checkup', 'Injury', 'Allergy', 'Surgery Consultation', 'COVID-19 Test']

# Create date range from April 1 to May 31, 2025
date_range = pd.date_range(start='2025-04-01', end='2025-05-31')
data = []

for date in date_range:
    for _ in range(random.randint(5, 10)):  # 5–10 visits per day
        visit_time = datetime.combine(date, datetime.min.time()) + timedelta(
            hours=random.randint(7, 17), minutes=random.randint(0, 59)
        )
        check_out_time = visit_time + timedelta(minutes=random.randint(15, 120))
        data.append({
            'patient_id': random.randint(50000, 99999),
            'hospital': random.choice(hospitals),
            'visit_date': date.date().isoformat(),
            'visit_reason': random.choice(visit_reasons),
            'cost': random.randint(50, 1500),
            'check_out_time': check_out_time.isoformat()
        })

# Save dataset to CSV and preview
df = pd.DataFrame(data)
df.to_csv('hospital_visits_apr_may.csv', index=False)
df.head(60)
# Out:
#     patient_id                hospital  visit_date          visit_reason  \
# 0        82823          Sunrise Health  2025-04-01                   Flu
# 1        92119     Green Valley Clinic  2025-04-01                   Flu
# 2        59283     Green Valley Clinic  2025-04-01       Routine Checkup
# 3        73539     Green Valley Clinic  2025-04-01               Allergy
# 4        86815           City Hospital  2025-04-01               Allergy
# 5        78168     Green Valley Clinic  2025-04-02         COVID-19 Test
# 6        74809  Oakwood Medical Center  2025-04-02         COVID-19 Test
# 7        80226  Oakwood Medical Center  2025-04-02  Surgery Consultation
# 8        52328  Oakwood Medical Center  2025-04-02               Allergy
# 9        97346           City Hospital  2025-04-02                Injury
# 10       63492  Oakwood Medical Center  2025-04-02                Injury
# 11       54759     Green Valley Clinic  2025-04-03  Surgery Consultation
# 12       58914          Sunrise Health  2025-04-03         COVID-19 Test
# 13       56718          Sunrise Health  2025-04-03  Surgery Consultation
# 14       67794     Green Valley Clinic  2025-04-03               Allergy
# 15       59189     Green Valley Clinic  2025-04-03                Injury
# 16       64951          Sunrise Health  2025-04-03                Injury
# 17       83289          Sunrise Health  2025-04-03                Injury
# 18       83797           City Hospital  2025-04-04                   Flu
# 19       89948           City Hospital  2025-04-04  Surgery Consultation
# 20       56130          Sunrise Health  2025-04-04         COVID-19 Test
# 21       56601           City Hospital  2025-04-04                   Flu
# 22       97115           City Hospital  2025-04-04                   Flu
# 23       75471  Oakwood Medical Center  2025-04-04       Routine Checkup
# 24       62350     Green Valley Clinic  2025-04-04                   Flu
# 25       53087           City Hospital  2025-04-04                Injury
# 26       84078           City Hospital  2025-04-05         COVID-19 Test
# 27       68250           City Hospital  2025-04-05  Surgery Consultation
# 28       51036           City Hospital  2025-04-05               Allergy
# 29       93147          Sunrise Health  2025-04-05       Routine Checkup
# 30       89514  Oakwood Medical Center  2025-04-05                   Flu
# 31       58231     Green Valley Clinic  2025-04-05               Allergy
# 32       85257     Green Valley Clinic  2025-04-05               Allergy
# 34   178  2025-04-05T08:26:00
# 35   878  2025-04-06T14:10:00
# 36   477  2025-04-06T15:43:00
# 37    55  2025-04-06T10:47:00
# 38    60  2025-04-06T08:45:00
# 39   973  2025-04-06T13:27:00
# 40   999  2025-04-06T09:37:00
# 41  1493  2025-04-06T10:21:00
# 42   590  2025-04-07T12:00:00
# 43   783  2025-04-07T10:56:00
# 44   128  2025-04-07T16:30:00
# 45  1293  2025-04-07T13:13:00
# 46   973  2025-04-07T15:12:00
# 47  1203  2025-04-08T14:36:00
# 48  1288  2025-04-08T16:15:00
# 49   952  2025-04-08T13:17:00
# 50   397  2025-04-08T09:55:00
# 51   365  2025-04-08T16:02:00
# 52   430  2025-04-08T18:19:00
# 53   864  2025-04-08T17:29:00
# 54  1497  2025-04-08T11:58:00
# 55  1295  2025-04-08T18:19:00
# 56   301  2025-04-08T08:47:00
# 57  1318  2025-04-09T09:42:00
# 58   778  2025-04-09T11:23:00
# 59  1461  2025-04-09T07:42:00

# %%
 # FULL EXTRACTION
df_full = pd.read_csv("hospital_visits_apr_may.csv", parse_dates=["check_out_time"])
print(f"Pulled {len(df_full)} rows via full extraction.")
df_full.head()
# Out:
# Pulled 450 rows via full extraction.
#    patient_id        hospital  visit_date   visit_reason  cost  \
# 0       78672   City Hospital  2025-04-01         Injury  1474
# 1       88708   City Hospital  2025-04-01  COVID-19 Test  1406
# 2       85521  Sunrise Health  2025-04-01        Allergy  1191
# 3       58044  Sunrise Health  2025-04-01         Injury  1320
# 4       89564   City Hospital  2025-04-01  COVID-19 Test  1193
#
#        check_out_time
# 0 2025-04-01 18:25:00
# 1 2025-04-01 14:22:00
# 2 2025-04-01 11:34:00
# 3 2025-04-01 14:54:00
# 4 2025-04-01 11:01:00

# %%
# Set initial last extraction time (e.g., halfway through the data range)
with open("last_extraction.txt", "w") as f:
    f.write("2025-04-20 12:00:00")

# %%
# INCREMENTAL EXTRACTION

with open("last_extraction.txt", "r") as f:
    last_extraction = f.read().strip()
    
df = pd.read_csv("hospital_visits_apr_may.csv", parse_dates=["check_out_time"])
last_extraction_time = pd.to_datetime(last_extraction)
df_incremental = df[df['check_out_time'] > last_extraction_time]
print(f"Pulled {len(df_incremental)} new/updated rows since {last_extraction}.")
df_incremental.head()
# Out:
# Pulled 2 new/updated rows since 2025-05-31T14:34:00.
#      patient_id        hospital  visit_date   visit_reason  cost  \
# 445       70696  Sunrise Health  2025-05-31  COVID-19 Test  1203
# 446       75131  Sunrise Health  2025-05-31  COVID-19 Test  1171
#
#          check_out_time
# 445 2025-05-31 16:00:00
# 446 2025-05-31 18:16:00

# %%
# Get the most recent update
new_checkpoint = df['check_out_time'].max()

# %%
# Save it
with open("last_extraction.txt", "w") as f:
    f.write(new_checkpoint.isoformat())
print(f"Updated last_extraction.txt to {new_checkpoint}")
# Out:
# Updated last_extraction.txt to 2025-05-31 18:16:00
