# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import random

# Define hospital and visit reason options
hospitals = ['City Hospital', 'Green Valley Clinic', 'Sunrise Health', 'Oakwood Medical Center']
visit_reasons = ['Flu', 'Routine Checkup', 'Injury', 'Allergy', 'Surgery Consultation', 'COVID-19 Test']

# Create date range from April 1 to May 31, 2025
date_range = pd.date_range(start='2025-04-01', end='2025-05-31')
data = []

for date in date_range:
    for _ in range(random.randint(5, 10)):  # 5–10 visits per day
        visit_time = datetime.combine(date, datetime.min.time()) + timedelta(
            hours=random.randint(7, 17), minutes=random.randint(0, 59)
        )
        check_out_time = visit_time + timedelta(minutes=random.randint(15, 120))
        data.append({
            'patient_id': random.randint(50000, 99999),
            'hospital': random.choice(hospitals),
            'visit_date': date.date().isoformat(),
            'visit_reason': random.choice(visit_reasons),
            'cost': random.randint(50, 1500),
            'check_out_time': check_out_time.isoformat()
        })

# Save dataset to CSV and preview
df = pd.DataFrame(data)
df.to_csv('hospital_visits_apr_may.csv', index=False)
df.head(60)
# Out:
#     patient_id                hospital  visit_date          visit_reason  \
# 0        90279  Oakwood Medical Center  2025-04-01  Surgery Consultation
# 1        62589  Oakwood Medical Center  2025-04-01       Routine Checkup
# 2        55339          Sunrise Health  2025-04-01  Surgery Consultation
# 3        52447           City Hospital  2025-04-01       Routine Checkup
# 4        56889          Sunrise Health  2025-04-01               Allergy
# 5        70840           City Hospital  2025-04-01       Routine Checkup
# 6        90406     Green Valley Clinic  2025-04-01                Injury
# 7        57185     Green Valley Clinic  2025-04-02                   Flu
# 8        64272          Sunrise Health  2025-04-02  Surgery Consultation
# 9        65090          Sunrise Health  2025-04-02                   Flu
# 10       55581     Green Valley Clinic  2025-04-02         COVID-19 Test
# 11       90920          Sunrise Health  2025-04-02         COVID-19 Test
# 12       84347          Sunrise Health  2025-04-02       Routine Checkup
# 13       52238          Sunrise Health  2025-04-03         COVID-19 Test
# 14       79858           City Hospital  2025-04-03       Routine Checkup
# 15       59564          Sunrise Health  2025-04-03  Surgery Consultation
# 16       59405          Sunrise Health  2025-04-03                Injury
# 17       98728     Green Valley Clinic  2025-04-03                Injury
# 18       90983          Sunrise Health  2025-04-03  Surgery Consultation
# 19       68724           City Hospital  2025-04-03                   Flu
# 20       82881  Oakwood Medical Center  2025-04-03         COVID-19 Test
# 21       60163           City Hospital  2025-04-04  Surgery Consultation
# 22       59058           City Hospital  2025-04-04       Routine Checkup
# 23       86959     Green Valley Clinic  2025-04-04  Surgery Consultation
# 24       57130           City Hospital  2025-04-04         COVID-19 Test
# 25       77026          Sunrise Health  2025-04-04                   Flu
# 26       58403  Oakwood Medical Center  2025-04-04                Injury
# 27       98570          Sunrise Health  2025-04-04       Routine Checkup
# 28       98854  Oakwood Medical Center  2025-04-04                Injury
# 29       56098  Oakwood Medical Center  2025-04-05                   Flu
# 30       62566  Oakwood Medical Center  2025-04-05               Allergy
# 31   684  2025-04-05T12:01:00
# 32  1415  2025-04-05T10:34:00
# 33   725  2025-04-05T11:21:00
# 34   455  2025-04-06T18:18:00
# 35  1283  2025-04-06T11:42:00
# 36   246  2025-04-06T12:35:00
# 37   336  2025-04-06T18:46:00
# 38  1017  2025-04-06T13:09:00
# 39  1388  2025-04-06T10:05:00
# 40  1497  2025-04-06T08:43:00
# 41  1199  2025-04-06T18:15:00
# 42  1276  2025-04-07T17:24:00
# 43   142  2025-04-07T08:36:00
# 44   641  2025-04-07T17:56:00
# 45   409  2025-04-07T12:55:00
# 46  1226  2025-04-07T18:06:00
# 47  1234  2025-04-08T09:15:00
# 48  1199  2025-04-08T08:12:00
# 49   758  2025-04-08T08:05:00
# 50  1338  2025-04-08T14:15:00
# 51  1067  2025-04-08T17:28:00
# 52   863  2025-04-09T17:35:00
# 53  1172  2025-04-09T12:47:00
# 54   322  2025-04-09T13:19:00
# 55   751  2025-04-09T09:25:00
# 56  1167  2025-04-09T10:51:00
# 57   647  2025-04-10T10:47:00
# 58   375  2025-04-10T17:15:00
# 59   255  2025-04-10T14:29:00

# %%
 # FULL EXTRACTION
df_full = pd.read_csv("hospital_visits.csv", parse_dates=["check_out_time"])
print(f"Pulled {len(df_full)} rows via full extraction.")
df_full.head()
# Out:
# Pulled 453 rows via full extraction.
#    patient_id                hospital  visit_date          visit_reason  cost  \
# 0       60542          Sunrise Health  2025-04-02  Surgery Consultation   332
# 1       72600  Oakwood Medical Center  2025-04-02                Injury   194
# 2       75961  Oakwood Medical Center  2025-04-02                Injury  1076
# 3       96648     Green Valley Clinic  2025-04-02       Routine Checkup  1468
# 4       81979     Green Valley Clinic  2025-04-02               Allergy    64
#
#        check_out_time
# 0 2025-04-02 10:00:00
# 1 2025-04-02 14:01:00
# 2 2025-04-02 15:38:00
# 3 2025-04-02 11:09:00
# 4 2025-04-02 10:14:00

# %%
# Set initial last extraction time (e.g., halfway through the data range)
with open("last_extraction.txt", "w") as f:
    f.write("2025-04-20 12:00:00")

# %%
# INCREMENTAL EXTRACTION

with open("last_extraction.txt", "r") as f:
    last_extraction = f.read().strip()
    
df = pd.read_csv("hospital_visits.csv", parse_dates=["check_out_time"])
last_extraction_time = pd.to_datetime(last_extraction)
df_incremental = df[df['check_out_time'] > last_extraction_time]
print(f"Pulled {len(df_incremental)} new/updated rows since {last_extraction}.")
df_incremental.head()
# Out:
# Pulled 0 new/updated rows since 2025-05-31 19:42:00.
# Empty DataFrame
# Columns: [patient_id, hospital, visit_date, visit_reason, cost, check_out_time]
# Index: []

# %%
# Get the most recent update
new_checkpoint = df['check_out_time'].max()

# %%
# Save it
with open("last_extraction.txt", "w") as f:
    f.write(new_checkpoint.isoformat())
print(f"Updated last_extraction.txt to {new_checkpoint}")
# Out:
# Updated last_extraction.txt to 2025-05-31 14:34:00
